# %% [markdown]
# # Customer Intelligence / Country Segmentation Notebook
#
# ## Unsupervised Learning on Country Data
#
#
# ### Goals
# - Load and inspect the data
# - Clean and preprocess features
# - Apply scaling
# - Find the best number of clusters with K-Means
# - Try DBSCAN as a second clustering method
# - Visualize clusters with PCA
# - Create simple country-level insights

# %% [markdown]
# ## 1) Import libraries

# %%
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

sns.set(style='whitegrid')
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2) Load the dataset
#
# Upload the CSV file from Kaggle when prompted.

# %%
df = pd.read_csv("Country-data.csv")
print(f'Dataset loaded: {df.shape[0]} rows × {df.shape[1]} columns')
df.head()
# Out:
# Dataset loaded: 167 rows × 10 columns
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %% [markdown]
# ## 3) Quick inspection

# %%
print('Shape:', df.shape)
display(df.head())
display(df.info())
display(df.describe(include='all').T)
# Out:
# Shape: (167, 10)
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
# ...

# %% [markdown]
# ## 4) Expected columns
#
# This dataset is commonly used for country clustering and usually contains:
# - country
# - child_mort
# - exports
# - health
# - imports
# - income
# - inflation
# - life_expec
# - total_fer
# - gdpp

# %%
print('Columns:', df.columns.tolist())
# Out:
# Columns: ['country', 'child_mort', 'exports', 'health', 'imports', 'income', 'inflation', 'life_expec', 'total_fer', 'gdpp']

# %% [markdown]
# ## 5) Basic cleaning
#
# Handle missing values, remove duplicates, and make sure numeric columns are clean.

# %%
df = df.copy()
df.columns = [c.strip().lower() for c in df.columns]
df = df.drop_duplicates()

for col in df.columns:
    if col != 'country':
        df[col] = pd.to_numeric(df[col], errors='coerce')

numeric_cols = [c for c in df.columns if c != 'country']
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

df.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# ## 6) Exploratory Data Analysis

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot: {col}')
    plt.show()

# %% [markdown]
# ## 7) Feature scaling
#
# Clustering works better when features are on the same scale.

# %%
features = df.drop(columns=['country'], errors='ignore')
scaler = StandardScaler()
X_scaled = scaler.fit_transform(features)
X_scaled.shape
# Out:
# (167, 9)

# %% [markdown]
# ## 8) K-Means: Elbow method

# %%
inertias = []
k_values = range(2, 11)

for k in k_values:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(X_scaled)
    inertias.append(model.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(list(k_values), inertias, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## 9) Train K-Means

# %%
best_k = 3  # change after checking the elbow plot
kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
df['kmeans_cluster'] = kmeans.fit_predict(X_scaled)

score = silhouette_score(X_scaled, df['kmeans_cluster'])
print(f"Silhouette Score: {score:.4f}")
df[['country', 'kmeans_cluster']].head() if 'country' in df.columns else df[['kmeans_cluster']].head()
# Out:
# Silhouette Score: 0.2833
#                country  kmeans_cluster
# 0          Afghanistan               1
# 1              Albania               2
# 2              Algeria               2
# 3               Angola               1
# 4  Antigua and Barbuda               2

# %% [markdown]
# ## 10) Try DBSCAN

# %%
dbscan = DBSCAN(eps=1.5, min_samples=5)
df['dbscan_cluster'] = dbscan.fit_predict(X_scaled)

print(df['dbscan_cluster'].value_counts().sort_index())
# Out:
# dbscan_cluster
# -1     30
#  0    137
# Name: count, dtype: int64

# %% [markdown]
# ## 11) PCA visualization

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

viz = pd.DataFrame({
    'pca1': X_pca[:, 0],
    'pca2': X_pca[:, 1],
    'cluster': df['kmeans_cluster']
})

plt.figure(figsize=(8, 6))
sns.scatterplot(data=viz, x='pca1', y='pca2', hue='cluster', palette='tab10')
plt.title('K-Means Clusters Visualized with PCA')
plt.show()

# %% [markdown]
# ## 12) Cluster profiling

# %%
profile = df.groupby('kmeans_cluster')[numeric_cols].mean().round(2)
profile
# Out:
#                 child_mort  exports  health  imports    income  inflation  \
# kmeans_cluster
# 0                     5.00    58.74    8.81    51.49  45672.22       2.67
# 1                    92.96    29.15    6.39    42.32   3942.40      12.02
# 2                    21.93    40.24    6.20    47.47  12305.60       7.60
#
#                 life_expec  total_fer      gdpp
# kmeans_cluster
# 0                    80.13       1.75  42494.44
# 1                    59.19       5.01   1922.38
# 2                    72.81       2.31   6486.45

# %% [markdown]
# ## 13) Final Insights
#
# 1. Which cluster has high child mortality?
#
# Cluster 0 has the highest child mortality rates and the lowest life expectancy. Most countries in this cluster are developing nations with limited healthcare facilities, poor sanitation, and lower living standards.
#
# 2. Which cluster has high income and GDP per capita?
#
# Cluster 1 consists of economically developed countries with the highest GDP per capita, strong trade performance, and low child mortality rates. These countries generally have advanced healthcare, education, and infrastructure systems.
#
# 3. Which cluster appears underdeveloped?
#
# Cluster 0 is the most underdeveloped cluster, characterized by low income levels, lower life expectancy, high child mortality, and weaker economic indicators compared to other clusters.
#
# 4. Which countries should be prioritized for aid?
#
# Countries belonging to Cluster 0 should receive the highest priority for international aid and development programs because they face significant challenges in healthcare, economic growth, and quality of life.
#
# 5. Overall Conclusion
#
# The clustering successfully grouped countries based on socio-economic and health indicators. The results clearly distinguish developed, developing, and underdeveloped nations, providing valuable insights for policy-making and resource allocation.
